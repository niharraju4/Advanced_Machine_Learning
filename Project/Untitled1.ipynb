# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.pipeline import Pipeline

# Load the data
merged_data = pd.read_csv('merged_data.csv')

# %%
# Check the first few rows of the data
merged_data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 2  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You    This help eating healthy exercise regular basis
# 4  10 Best Foods for You         Works great especially going grocery store
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity            Category  \
# 0  Positive                1.00                0.533333  HEALTH_AND_FITNESS
# 1  Positive                1.00                0.533333  HEALTH_AND_FITNESS
# 2  Positive                0.25                0.288462  HEALTH_AND_FITNESS
# 3  Positive                0.25                0.288462  HEALTH_AND_FITNESS
# 4  Positive                0.40                0.875000  HEALTH_AND_FITNESS
#
# ...

# %%
merged_data.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# Content Rating            0
# Genres                    0
# Last Updated              0
# Current Ver               0
# Android Ver               0
# dtype: int64

# %%
merged_data.dropna(inplace=True)

# %%
merged_data['Installs'] = merged_data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 merged_data['Installs'] = merged_data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
# Convert 'Price' to numerical
merged_data['Price'] = merged_data['Price'].str.replace('$', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Convert 'Price' to numerical
# ----> 2 merged_data['Price'] = merged_data['Price'].str.replace('$', '').astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
# Distribution of app ratings
plt.figure(figsize=(8, 6))
sns.histplot(merged_data['Rating'], bins=20, kde=True)
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# Distribution of app installs
plt.figure(figsize=(8, 6))
sns.histplot(np.log1p(merged_data['Installs']), bins=20, kde=True)
plt.title('Distribution of App Installs (Log Scale)')
plt.xlabel('Log(Installs)')
plt.ylabel('Frequency')
plt.show()

# Distribution of app prices
plt.figure(figsize=(8, 6))
sns.histplot(merged_data['Price'], bins=20, kde=True)
plt.title('Distribution of App Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\nihar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nihar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nihar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Convert 'Category' to categorical
merged_data['Category'] = merged_data['Category'].astype('category').cat.codes

# Define features and target variable
X = merged_data[['Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating']]
y = merged_data['Rating'].apply(lambda x: 1 if x >= 4.0 else 0)  # Binary classification: Good (1) or Not Good (0)

# Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['Reviews', 'Size', 'Installs', 'Price']),
        ('cat', OneHotEncoder(), ['Category', 'Type', 'Content Rating'])
    ]
)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Decision Tree pipeline
dt_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', DecisionTreeClassifier(random_state=42))
])

# Fit the model
dt_pipeline.fit(X_train, y_train)

# Make predictions
y_pred_dt = dt_pipeline.predict(X_test)

# Evaluate the model
print("Decision Tree Classifier:")
print(classification_report(y_test, y_pred_dt))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7500\415699379.py in ?()
#       4     ('classifier', DecisionTreeClassifier(random_state=42))
#       5 ])
#       6
#       7 # Fit the model
# ----> 8 dt_pipeline.fit(X_train, y_train)
#       9
#      10 # Make predictions
#      11 y_pred_dt = dt_pipeline.predict(X_test)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(self, X, y, **fit_params)
#     397         self : object
#     398             Pipeline with fitted steps.
#     399         """
#     400         fit_params_steps = self._check_fit_params(**fit_params)
# --> 401         Xt = self._fit(X, y, **fit_params_steps)
#     402         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403             if self._final_estimator != "passthrough":
# ...
